# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('new_retail_data.csv')

cols = ["Transaction_ID", "Customer_ID", "Zipcode", "Ratings", "Total_Purchases", 'Age']
df[cols] = df[cols].astype("Int64")

df.head()
# Out:
#    Transaction_ID  Customer_ID                 Name                Email  \
# 0         8691788        37249  Michelle Harrington    Ebony39@gmail.com
# 1         2174773        69749          Kelsey Hill     Mark36@gmail.com
# 2         6679610        30192         Scott Jensen    Shane85@gmail.com
# 3         7232460        62101        Joseph Miller     Mary34@gmail.com
# 4         4983775        27901        Debra Coleman  Charles30@gmail.com
#
#           Phone                      Address        City            State  \
# 0  1.414787e+09            3959 Amanda Burgs    Dortmund           Berlin
# 1  6.852900e+09           82072 Dawn Centers  Nottingham          England
# 2  8.362160e+09            4133 Young Canyon     Geelong  New South Wales
# 3  2.776752e+09  8148 Thomas Creek Suite 100    Edmonton          Ontario
# 4  9.098268e+09    5813 Lori Ports Suite 269     Bristol          England
#
#    Zipcode    Country  Age  Gender Income Customer_Segment        Date  \
# 0    77985    Germany   21    Male    Low          Regular   9/18/2023
# 1    99071         UK   19  Female    Low          Premium  12/31/2023
# 2    75929  Australia   48    Male    Low          Regular   4/26/2023
# 3    88420     Canada   56    Male   High          Premium    5/8/2023
# 4    48704         UK   22    Male    Low          Premium   1/10/2024
#
#      Year      Month      Time  Total_Purchases      Amount  Total_Amount  \
# 0  2023.0  September  22:03:55                3  108.028757    324.086270
# 1  2023.0   December   8:42:04                2  403.353907    806.707815
# 2  2023.0      April   4:06:29                3  354.477600   1063.432799
# 3  2023.0        May  14:55:17                7  352.407717   2466.854021
# 4  2024.0    January  16:54:07                2  124.276524    248.553049
#
#   Product_Category  Product_Brand Product_Type   Feedback Shipping_Method  \
# 0         Clothing           Nike       Shorts  Excellent        Same-Day
# 1      Electronics        Samsung       Tablet  Excellent        Standard
# 2            Books  Penguin Books   Children's    Average        Same-Day
# 3       Home Decor     Home Depot        Tools  Excellent        Standard
# 4          Grocery         Nestle    Chocolate        Bad        Standard
#
#   Payment_Method Order_Status  Ratings           products
# 0     Debit Card      Shipped        5     Cycling shorts
# 1    Credit Card   Processing        4         Lenovo Tab
# 2    Credit Card   Processing        2   Sports equipment
# 3         PayPal   Processing        4      Utility knife
# 4           Cash      Shipped        1  Chocolate cookies

# %%
#Remove customers that have different emails for the same customer id
valid_ids = (
    df.groupby("Customer_ID")["Email"]
    .nunique()
    .eq(1)
)

df_clean = df[df["Customer_ID"].isin(valid_ids[valid_ids].index)]

df = df_clean.copy()

df_clean.head()

print(len(df))
print(len(df_clean))
# Out:
# 10987
# 10987

# %%
customer_info_cols = ['Customer_ID', 'Name', 'Email', 'Phone', 'Address', 'City', 'State', 'Zipcode', 'Country', 'Age', 'Gender', 'Income', 'Customer_Segment']

# %%
#Save non-customer columns as transaction data columns
df_transactions = df.drop(columns=customer_info_cols[1:])

# Make transaction date and time into one timestamp column
df_transactions['Transaction_Date'] = pd.to_datetime(df_transactions['Date'] + ' ' + df_transactions['Time'])

#Also drop out Year, Month, Date columns
df_transactions = df_transactions.drop(columns=['Date', 'Time', 'Year', 'Month'])

#Show final transactions dataframe
df_transactions.head()
# Out:
#     Transaction_ID  Customer_ID  Total_Purchases      Amount  Total_Amount  \
# 8          4155845        80175                8  328.839302   2630.714413
# 15         4969987        64995                3   23.723901     71.171704
# 22         9476855        42410                6   34.124266    204.745598
# 30         3413296        98256                3  159.804193    479.412580
# 51         4580441        12911                3  394.606266   1183.818797
#
#    Product_Category  Product_Brand Product_Type   Feedback Shipping_Method  \
# 8           Grocery         Nestle    Chocolate        Bad        Same-Day
# 15            Books   Random House   Literature        Bad         Express
# 22            Books  Penguin Books  Non-Fiction    Average        Same-Day
# 30         Clothing         Adidas        Shoes       Good        Same-Day
# 51          Grocery         Nestle    Chocolate  Excellent         Express
#
#    Payment_Method Order_Status  Ratings         products    Transaction_Date
# 8            Cash    Delivered        1   Dark chocolate 2024-01-06 14:38:26
# 15    Credit Card      Pending        1            Drama 2023-06-15 23:24:22
# 22         PayPal   Processing        2        Self-help 2024-02-03 06:22:00
# 30     Debit Card      Pending        3    Running shoes 2024-02-06 01:59:20
# 51         PayPal   Processing        5  White chocolate 2023-11-11 15:38:31

# %%
# Rearrange column order

# Specify the column to move and the desired new position (index)
column_to_move = 'Transaction_Date'
new_position = 2 # To move to the first position

# 1. Use pop() to remove the column and store its data
col_data = df_transactions.pop(column_to_move)

# 2. Use insert() to place the column at the desired position
df_transactions.insert(new_position, column_to_move, col_data)

print("New DataFrame columns:", df_transactions.columns)

df_transactions.head()
# Out:
# New DataFrame columns: Index(['Transaction_ID', 'Customer_ID', 'Transaction_Date', 'Total_Purchases',
#        'Amount', 'Total_Amount', 'Product_Category', 'Product_Brand',
#        'Product_Type', 'Feedback', 'Shipping_Method', 'Payment_Method',
#        'Order_Status', 'Ratings', 'products'],
#       dtype='object')
#     Transaction_ID  Customer_ID    Transaction_Date  Total_Purchases  \
# 8          4155845        80175 2024-01-06 14:38:26                8
# 15         4969987        64995 2023-06-15 23:24:22                3
# 22         9476855        42410 2024-02-03 06:22:00                6
# 30         3413296        98256 2024-02-06 01:59:20                3
# 51         4580441        12911 2023-11-11 15:38:31                3
#
#         Amount  Total_Amount Product_Category  Product_Brand Product_Type  \
# 8   328.839302   2630.714413          Grocery         Nestle    Chocolate
# 15   23.723901     71.171704            Books   Random House   Literature
# 22   34.124266    204.745598            Books  Penguin Books  Non-Fiction
# 30  159.804193    479.412580         Clothing         Adidas        Shoes
# 51  394.606266   1183.818797          Grocery         Nestle    Chocolate
#
#      Feedback Shipping_Method Payment_Method Order_Status  Ratings  \
# 8         Bad        Same-Day           Cash    Delivered        1
# 15        Bad         Express    Credit Card      Pending        1
# 22    Average        Same-Day         PayPal   Processing        2
# 30       Good        Same-Day     Debit Card      Pending        3
# 51  Excellent         Express         PayPal   Processing        5
#
#            products
# 8    Dark chocolate
# 15            Drama
# 22        Self-help
# 30    Running shoes
# 51  White chocolate

# %%
df_customer_info = df[customer_info_cols]

# Convert phone number from float to string
df_customer_info['Phone'] = df_customer_info['Phone'].fillna(0).astype('int64').astype('string')

df_customer_info.head()
# Out:
# C:\Users\urvij\AppData\Local\Temp\ipykernel_14472\2586289450.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_customer_info['Phone'] = df_customer_info['Phone'].fillna(0).astype('int64').astype('string')
#     Customer_ID               Name               Email       Phone  \
# 8         80175        Diane Clark  Martin39@gmail.com  6219779557
# 15        64995        Justin Lara   Jacob26@gmail.com  2683281702
# 22        42410  Anthony Rodriguez   Paula49@gmail.com  3745118170
# 30        98256        Steven Boyd  Sheryl18@gmail.com  5248581519
# 51        12911   Chelsea Cummings  Daniel55@gmail.com  9050662623
#
#                             Address        City            State  Zipcode  \
# 8      8823 Mariah Heights Apt. 263  Wollongong  New South Wales    39820
# 15        3577 Cole Stream Apt. 351  Portsmouth          England     9845
# 22        585 Malik Lodge Suite 186  Portsmouth          England    83903
# 30  1719 Christina Heights Apt. 614  Portsmouth          England    43602
# 51                     336 Sara Run  Portsmouth          England    27283
#
#       Country  Age  Gender  Income Customer_Segment
# 8   Australia   46    Male  Medium              New
# 15         UK   43    Male  Medium          Regular
# 22         UK   21  Female     Low          Regular
# 30         UK   26  Female     Low          Regular
# 51         UK   69    Male    High          Regular

# %%
# Write separated dataframes to CSV
df_transactions.to_csv('retail_transactions.csv', index=False)
df_customer_info.to_csv('retail_customers.csv', index=False)

# %%
# Show transaction dataset columns
df_transactions.columns.str.upper()
# Out:
# Index(['TRANSACTION_ID', 'CUSTOMER_ID', 'TRANSACTION_DATE', 'TOTAL_PURCHASES',
#        'AMOUNT', 'TOTAL_AMOUNT', 'PRODUCT_CATEGORY', 'PRODUCT_BRAND',
#        'PRODUCT_TYPE', 'FEEDBACK', 'SHIPPING_METHOD', 'PAYMENT_METHOD',
#        'ORDER_STATUS', 'RATINGS', 'PRODUCTS'],
#       dtype='object')

# %%
# Show customer info dataset columns
df_customer_info.columns.str.upper()
# Out:
# Index(['CUSTOMER_ID', 'NAME', 'EMAIL', 'PHONE', 'ADDRESS', 'CITY', 'STATE',
#        'ZIPCODE', 'COUNTRY', 'AGE', 'GENDER', 'INCOME', 'CUSTOMER_SEGMENT'],
#       dtype='object')

# %%
df_customer_info.dtypes
# Out:
# Customer_ID                  Int64
# Name                        object
# Email                       object
# Phone               string[python]
# Address                     object
# City                        object
# State                       object
# Zipcode                      Int64
# Country                     object
# Age                          Int64
# Gender                      object
# Income                      object
# Customer_Segment            object
# dtype: object

# %%
df_clean.sample(1000).to_csv('retail_dataset_sample.csv', index=False)
